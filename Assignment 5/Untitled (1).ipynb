# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
ax = fig.add_axes([0,0,1,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4d0503a6c92a> in <module>()
#       2 get_ipython().magic('matplotlib inline')
#       3 import pandas as pd
# ----> 4 ax = fig.add_axes([0,0,1,1])
#
# NameError: name 'fig' is not defined

# %%
df=pd.read_csv('recent-grads.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-48a21b51b25b> in <module>()
# ----> 1 df=pd.read_csv('recent-grads.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
# ...

# %%
df
# Out:
#      Rank                                      Major  \
# 0       1                      PETROLEUM ENGINEERING
# 1       2             MINING AND MINERAL ENGINEERING
# 2       3                  METALLURGICAL ENGINEERING
# 3       4  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5                       CHEMICAL ENGINEERING
# ..    ...                                        ...
# 168   169                                    ZOOLOGY
# 169   170                     EDUCATIONAL PSYCHOLOGY
# 170   171                        CLINICAL PSYCHOLOGY
# 171   172                      COUNSELING PSYCHOLOGY
# 172   173                            LIBRARY SCIENCE
#
#                Major_category  Employed  Full_time  Part_time  Unemployed  \
# 0                 Engineering      1976       1849        270          37
# 1                 Engineering       640        556        170          85
# 2                 Engineering       648        558        133          16
# ...

# %%
plt.figure()
ax=df.plot(y='Employed', x='Major')
fig.tight_layout()

plt.show()
ax.set_xlabel('Major')
ax.set_ylabel('Employed')
# Out:
# Text(9.794318181818184, 0.5, 'Employed')

# %%
df.plot(subplots=True, layout=(2,3))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
plt.bar( df['Major_category'],df['Employed'] , color ='maroon')
plt.xlabel('Major')
plt.ylabel('Students')
plt.title('Employment rate')
fig.autofmt_xdate()

plt.show()

# %%
plt.hist(df['Major_category'],bins = 10)
plt.xlabel('Major Category')
plt.ylabel('Range')
plt.title('Major Category Details')
plt.show()

# %%
plt.hist(df['Major'],bins = 20)
plt.xlabel('Major Category')
plt.ylabel('Range')
plt.title('Major Details')

plt.show()

# %%
ax=plt.scatter( df['Part_time'],df['Full_time'])
plt.legend(["Part time"],loc="lower right")
plt.xlabel("Part time")
plt.ylabel("Full Time Employment")
plt.title('Scatter Plot')

plt.show()
